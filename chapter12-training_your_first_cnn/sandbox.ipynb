# %%
# %run shallownet_animals.py --dataset ../datasets/animals
# Out:
# [INFO] loading images...
# [INFO] processed 500/3000
# [INFO] processed 1000/3000
# [INFO] processed 1500/3000
# [INFO] processed 2000/3000
# [INFO] processed 2500/3000
# [INFO] processed 3000/3000
# [INFO] compiling model...
# [INFO] training network...
# Epoch 1/100
# 71/71 [==============================] - 1s 11ms/step - loss: 1.0585 - acc: 0.4028 - val_loss: 0.9809 - val_acc: 0.4453
# Epoch 2/100
# 71/71 [==============================] - 1s 9ms/step - loss: 0.9368 - acc: 0.5338 - val_loss: 0.9602 - val_acc: 0.5333
# Epoch 3/100
# 71/71 [==============================] - 1s 12ms/step - loss: 0.9062 - acc: 0.5316 - val_loss: 1.0442 - val_acc: 0.5120
# Epoch 4/100
# 71/71 [==============================] - 1s 10ms/step - loss: 0.9087 - acc: 0.5348 - val_loss: 0.8883 - val_acc: 0.5293
# Epoch 5/100
# 71/71 [==============================] - 1s 10ms/step - loss: 0.8466 - acc: 0.6041 - val_loss: 0.8803 - val_acc: 0.5480
# Epoch 6/100
# ...

# %%
# %run shallownet_cifar10.py
# Out:
# 2022-07-27 03:18:43.367029: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# [INFO] loading CIFAR-10 data...
# [INFO] compiling model...
# [INFO] training network...
# 2022-07-27 03:18:47.260606: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-07-27 03:18:47.260951: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-07-27 03:18:47.260967: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-07-27 03:18:47.261005: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (02fb3af1f1bd): /proc/driver/nvidia/version does not exist
# ...
